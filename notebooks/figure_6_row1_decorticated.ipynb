# %%
# %run utils.ipynb
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %matplotlib inline
#%matplotlib notebook

# %%
fps=4
raster = np.load("../data/f6_2_raster.npy").T
raster=np.delete(raster, np.where(np.sum(raster,axis=1)==0)[0],axis=0).copy()
plot_raster(raster,fps)
#plt.savefig('../figures/raster.svg', format='svg', dpi=300, transparent=True)

# %%
mapper = umap.UMAP(n_neighbors=5,min_dist=0.1,n_components=3,random_state=42,metric='correlation',).fit(raster)
ma=get_adj_matrix(mapper)
plt.matshow(ma,cmap='Blues')
plt.colorbar()
#plt.savefig('../figures/adj_matrix.svg', format='svg', dpi=300, transparent=True)
plt.show()

# %%
cluster_index,mat_mismo_grupo=get_clusters_modularidad(ma,n_iter=1000)
# Out:
# Number of Ensembles:  15

# %%
ord_plot_ch=plot_cluster_raster(raster,fps,cluster_index,name_colormap='nipy_spectral')
#plt.savefig('../figures/ensamble_raster.svg', format='svg', dpi=300,transparent=True)

# %%
test_coactivity_is_random(raster,cluster_index,1000)
# Out:
# Cluster 0
# rt = -31.932382813161357
# p = 9.489011785713643e-224
# alphahat 0.0
# betahat 0.0
#
# Cluster 1
# rt = -33.218836669870214
# p = 5.755897875938374e-242
# alphahat 0.0
# betahat 0.0
#
# Cluster 2
# rt = -31.7474173332597
# p = 3.4468454153365257e-221
# alphahat 0.0
# betahat 0.0
#
# Cluster 3
# rt = -32.842174557164284
# p = 1.4732005689898729e-236
# alphahat 0.0
# betahat 0.0
#
# Cluster 4
# rt = -32.63671524366679
# p = 1.2368524933001864e-233
# alphahat 0.0
# betahat 0.0
#
# Cluster 5
# rt = -31.93819176415746
# p = 7.880902387806256e-224
# alphahat 0.0
# betahat 0.0
#
# Cluster 6
# rt = -32.56544830536291
# p = 1.2655995564924682e-232
# alphahat 0.0
# betahat 0.0
#
# Cluster 7
# rt = -30.2444678258389
# p = 6.168722520658557e-201
# alphahat 0.0
# betahat 0.0
#
# Cluster 8
# rt = -32.56870132894109
# p = 1.1382645818788759e-232
# alphahat 0.0
# betahat 0.0
#
# Cluster 9
# rt = -30.869280020776127
# p = 3.0878047203787574e-209
# alphahat 0.0
# betahat 0.0
#
# Cluster 10
# rt = -33.32556149576507
# p = 1.6464782682759307e-243
# alphahat 0.0
# betahat 0.0
#
# Cluster 11
# rt = -32.01994608370407
# p = 5.754884464412207e-225
# alphahat 0.0
# betahat 0.0
#
# Cluster 12
# rt = -32.79389474494905
# p = 7.19476918316553e-236
# alphahat 0.0
# betahat 0.0
#
# Cluster 13
# rt = -32.599692664954965
# p = 4.142555088930213e-233
# alphahat 0.0
# betahat 0.0
#
# Cluster 14
# rt = -31.26237582829471
# p = 1.5157516033689887e-214
# alphahat 0.0
# betahat 0.0

# %%
plot_coactivity_ensambles(raster,cluster_index,1000,'nipy_spectral',fps,20,3)
#plt.savefig('../figures/coactivity_ensamble_rasters.svg', format='svg', dpi=300,transparent=True)

# %%
ord_plot_ch,ensembles_in_time=plot_ensamble_raster(raster,fps,cluster_index,'nipy_spectral',3,20,5)
#plt.savefig('../figures/ensamble_raster.svg', format='svg', dpi=300,transparent=True)

# %%
df=get_recurrence_analysis(raster,cluster_index)

# %%
recurrence_matrix=plot_rate(raster,cluster_index,11,bin_=4,fps=4,r=3)
plt.ylim(0,30)
#plt.savefig('../figures/ensemble_rate.svg', format='svg', dpi=300,transparent=True)
# Out:
# (0.0, 30.0)

# %%
plt.matshow(recurrence_matrix,cmap='Blues')
plt.colorbar()
#plt.savefig('../figures/recurrence_matrix.svg', format='svg', dpi=300,transparent=True)
