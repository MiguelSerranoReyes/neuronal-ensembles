# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import umap.plot
from IPython.core.display import display, HTML
from pyrqa.time_series import TimeSeries
from pyrqa.settings import Settings
from pyrqa.analysis_type import Classic
from pyrqa.neighbourhood import FixedRadius, RadiusCorridor
from pyrqa.metric import EuclideanMetric, MaximumMetric, TaxicabMetric
from pyrqa.computation import RQAComputation
from pyrqa.computation import RPComputation
from pyrqa.image_generator import ImageGenerator
from tqdm.notebook import tqdm
import umap
from pyrqa.neighbourhood import Unthresholded
display(HTML("<style>.container { width:95% !important; }</style>"))

# %%
# %run utils.ipynb

# %%
path=os.getcwd()
exp=path[path.rindex('\\')+1:]
if exp[0:2]=='CT':
    cond='Control'
elif exp[0:2]=='DE':
    cond='Decorticated'
elif exp[0:2]=='DY':
    cond='Dyskinesia'
elif exp[0:2]=='PR':
    cond='Parkinson'
nombre_proyecto='Datos-Jesus-Perez-Ortega'
imagenologia_util=path[:int(path.find(nombre_proyecto)+len(nombre_proyecto)+1)]+"Utilidades\\imagenologia_utilidades.ipynb"
# %run $imagenologia_util

# %%
plt.rcParams['svg.fonttype'] = 'none'

# %%
fps=4
raster = np.load(exp+"_raster.npy").T
raster=np.delete(raster, np.where(np.sum(raster,axis=1)==0)[0],axis=0).copy()
plot_raster(raster,fps,smoothing=False)
plt.savefig('raster_normal.svg', format='svg', dpi=300,transparent=True)

# %%
n_vecinos=int(np.round(np.sqrt(raster.shape[0])))
n_vecinos
# Out:
# 10

# %%
# %matplotlib inline
mapper = umap.UMAP(n_neighbors=5,min_dist=0.1,n_components=3,random_state=42,metric='correlation',).fit(raster)
#umap.plot.connectivity(mapper, show_points=True)

# %%
ma=np.zeros(mapper.graph_.shape)
contador=0
for i in range(ma.shape[0]):
    tam=mapper.graph_.indptr[i+1]-mapper.graph_.indptr[i]
    ma[i,mapper.graph_.indices[contador:contador+tam]]=mapper.graph_.data[contador:contador+tam]
    contador+=tam
plt.matshow(ma,cmap='Blues')
plt.colorbar()
plt.savefig('matriz_normal.svg', format='svg', dpi=300,transparent=True)

# %%
cluster_index,mat_mismo_grupo=get_clusters_modularidad(ma,n_iter=1000)
# Out:
# Número de Grupos:  9

# %%
cluster_index=nuevo_cluster_index(cluster_index,[8,6,2,0,5,1,4,3,7])

# %%
mapper = umap.UMAP(n_neighbors=5,min_dist=0.1,n_components=3,random_state=42,metric='correlation').fit(raster)
# %matplotlib inline
fig = plt.figure()
plt.rcParams['grid.color'] = (0.5, 0.5, 0.5, 0.1)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(
    mapper.embedding_[:, 0],
    mapper.embedding_[:, 1],
    mapper.embedding_[:, 2],
    c=cluster_index, cmap='tab10')
plt.savefig('proyeccion_neuronas.svg', format='svg', dpi=300,transparent=True)

# %%
fig = plt.figure(figsize=(10,3))

ax = fig.add_subplot(131)
ax.scatter(
    mapper.embedding_[:, 0],
    mapper.embedding_[:, 1],
    alpha=0.6,
    c=cluster_index, cmap='tab10')

ax = fig.add_subplot(132)
ax.scatter(
    mapper.embedding_[:, 0],
    mapper.embedding_[:, 2],
    alpha=0.6,
    c=cluster_index, cmap='tab10')

ax = fig.add_subplot(133)
ax.scatter(
    mapper.embedding_[:, 1],
    mapper.embedding_[:, 2],
    alpha=0.6,
    c=cluster_index, cmap='tab10')
plt.savefig('proyeccion_neuronas_planos.svg', format='svg', dpi=300,transparent=True)

# %%
ma_ordered=np.zeros(ma.shape)
count=0
new_order=[]
for ci in range(max(cluster_index)+1):
    indices_ci=np.where(cluster_index==ci)[0]
    for indice in indices_ci:
        new_order.append(indice)
        count+=1
for i in range(len(new_order)):
    indices_i=np.where(ma[new_order[i],:]>0)[0]
    for indice in indices_i:
        ma_ordered[i,np.where(new_order==indice)[0]]=ma[new_order[i],indice]
plt.matshow(ma_ordered,cmap='Blues')
plt.colorbar()
plt.savefig('matriz_ordenada.svg', format='svg', dpi=300,transparent=True)

# %%
ma_reduced=threshold_proportional(ma, 0.03)
G=nx.from_numpy_matrix(ma_reduced)
ensemble_attr_dict={}
color_attr_dict={}
cmap = matplotlib.cm.get_cmap('tab10')
for i,ci in enumerate(cluster_index):
    ensemble_attr_dict[i]=str(ci)
    v=list(cmap(ci)[0:3])
    v=[vi*255 for vi in v]
    l=len(str(v))-1
    color_attr_dict[i]=str(v)[1:l]
nx.set_node_attributes(G,  ensemble_attr_dict, "ensemble")
nx.set_node_attributes(G, color_attr_dict,"color")
ma_ordered=np.zeros(ma_reduced.shape)
count=0
new_order=[]
for ci in range(max(cluster_index)+1):
    indices_ci=np.where(cluster_index==ci)[0]
    for indice in indices_ci:
        new_order.append(indice)
        count+=1
for i in range(len(new_order)):
    indices_i=np.where(ma_reduced[new_order[i],:]>0)[0]
    for indice in indices_i:
        ma_ordered[i,np.where(new_order==indice)[0]]=ma_reduced[new_order[i],indice]
plt.matshow(ma_ordered,cmap='cividis')
plt.colorbar()
nx.write_gml(G, "DEC230513A.gml")

# %%
# %matplotlib inline

ord_plot_ch=plot_cluster_raster_h(raster,fps,cluster_index,name_colormap='tab10')
plt.savefig('raster_esambles.svg', format='svg', dpi=300,transparent=True)

# %%
raster_s=raster_subrogado(raster,1)
plot_raster(raster_s,fps,smoothing=False)

# %%
raster_s=raster_subrogado(raster,2)
plot_raster(raster_s,fps,smoothing=False)

# %%
rt,p,alphahat,betahat=coactivity_is_random(raster,1000)
# Out:
# rt = -30.142870216196652
# p = 1.3301393464988193e-199
# alphahat 0.048
# betahat 0.0

# %%
test_coactivity_is_random(raster,cluster_index,1000)
# Out:
# Cluster 0
# rt = -38.25423061624828
# p = 0.0
# alphahat 0.0
# betahat 0.0
#
# Cluster 1
# rt = -34.54964144185882
# p = 1.443142267447115e-261
# alphahat 0.0
# betahat 0.0
#
# Cluster 2
# rt = -39.011563548130134
# p = 0.0
# alphahat 0.0
# betahat 0.0
#
# Cluster 3
# rt = -37.50550431929548
# p = 7.491678114534153e-308
# alphahat 0.0
# betahat 0.0
#
# Cluster 4
# rt = -38.05535509197644
# p = 0.0
# alphahat 0.0
# betahat 0.0
#
# Cluster 5
# rt = -38.76617327025587
# p = 0.0
# alphahat 0.0
# betahat 0.0
#
# Cluster 6
# rt = -38.23670376079558
# p = 0.0
# alphahat 0.0
# betahat 0.0
#
# Cluster 7
# rt = -37.460508868616635
# p = 4.051030208778977e-307
# alphahat 0.0
# betahat 0.0
#
# Cluster 8
# rt = -39.06003691820001
# p = 0.0
# alphahat 0.0
# betahat 0.0

# %%
plot_coactivity_ensambles(raster,np.zeros(cluster_index.shape),1000,'gray',fps,20,2)

# %%
plot_coactivity_ensambles(raster,cluster_index,1000,'tab10',fps,20,3)

# %%
ord_plot_ch,ensembles_in_time=plot_ensamble_raster(raster,fps,cluster_index,'tab10',3,20,5)

# %%
get_2D_projection_vectors(raster,cluster_index,'tab10',20,3,0.1,42,'euclidean')

# %%
#%matplotlib notebook
get_3D_projection_vectors(raster,cluster_index,'tab10',20,3,0.5,42,'euclidean')

# %%
df=get_recurrence_analysis(raster,cluster_index)

# %%
plot_coactivity_ensambles(raster,cluster_index,1000,'tab10',fps,20,3)

# %%
df
# Out:
#    Ensemble     N        RR       DET         L  L_max       DIV    L_entr  \
# 0       0.0   6.0  0.003815  0.779351  3.780609   26.0  0.038462  1.798392
# 1       1.0  19.0  0.056069  0.757047  3.402365   32.0  0.031250  1.628142
# 2       2.0   9.0  0.011031  0.803111  3.904507   34.0  0.029412  1.840314
# 3       3.0  12.0  0.019704  0.763024  3.487913   27.0  0.037037  1.670129
# 4       4.0   8.0  0.012475  0.794391  3.783766   26.0  0.038462  1.807055
# 5       5.0  12.0  0.016833  0.766310  3.849064   22.0  0.045455  1.838362
# 6       6.0  15.0  0.008777  0.742536  3.319389   26.0  0.038462  1.578849
# 7       7.0  17.0  0.021027  0.735742  3.370723   34.0  0.029412  1.608065
# 8       8.0   6.0  0.004857  0.740907  4.434316   23.0  0.043478  2.024271
#
#         LAM        TT  V_max    V_entr           W   W_max     W_div    W_entr
# 0  0.894506  0.894506   19.0  1.914601  598.143373  2158.0  0.000463  3.750027
# ...

# %%
plot_resume_recurrence(df)

# %%
filename='recurrence_data.xlsx'
path_df=path[:int(path.find(nombre_proyecto)+len(nombre_proyecto)+1)]+"Resultados\\"+filename
save_recurrence_data(df,path_df,exp,cond)

# %%
df_=pd.DataFrame(columns=['Experiment','Condition','Num_Neurons','Num_Ensembles'])
fila={'Experiment':exp,
     'Condition':cond,
     'Num_Neurons':raster.shape[0],
     'Num_Ensembles':max(cluster_index)+1}
df_=df_.append(fila, ignore_index=True)
filename='experiment_data.xlsx'
path_df_=path[:int(path.find(nombre_proyecto)+len(nombre_proyecto)+1)]+"Resultados\\"+filename
save_experiment_data(df_,path_df_)

# %%
df_
# Out:
#    Experiment     Condition Num_Neurons Num_Ensembles
# 0  DEC230513A  Decorticated         104             9
